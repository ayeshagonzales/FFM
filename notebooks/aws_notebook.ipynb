# %%
from utils.sagemaker_gpu_setup import SageMakerGPUManager

# Day 1: Create notebook
manager = SageMakerGPUManager()
name, url = manager.create_notebook_instance(volumesize=20)
# Click URL, upload your image, run your script

# %%
# End of day: Stop it (saves money, but continue to pay for storage)
manager.stop_notebook_instance(name)

# %%
# Day 2: Restart it
url = manager.start_notebook_instance(name)
# Continue working...

# %%
# Project done: Delete it; stops all billing
manager.delete_notebook_instance(name)
